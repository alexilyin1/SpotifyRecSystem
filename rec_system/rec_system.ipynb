# %%
import sys
import json
sys.path.insert(0, './CPPotify/source/py')
from CPPotify import CPPotify

import numpy as np
import pandas as pd

from utils.utils import cosine_similarity, jaccard_similarity, list_union
from keys import CLIENT_ID, CLIENT_SECRET, REDIRECT_URI, STATE, SCOPE, SHOW_DIALOG

# %%
pd.options.display.precision = 10

# %%
cpp = CPPotify(CLIENT_ID, CLIENT_SECRET, REDIRECT_URI, STATE, SCOPE, SHOW_DIALOG)

# %%
cpp.open_auth_url()

# %%
cpp.oAuth_flow('https://example.com/callback?code=AQCAV7JQ-ZQ-WSXAUmY8mN3yQTtTszywvtBdyalwo1264SeDGhDQ6SJARL7PABMuhYr6ekt0Qrsq1ghnYrvraI1VzGDX76ep6jLPwSUxxfPeTy3qQMBVnO83foqxs64p-rwtNBYm4s42Wl1GyqKpZsUA4lLlrUnKt_z-Qx8T26wID6YqCWLbToLruPGBlq4Ap-kjjAHi-R3J9-WHwCoCCyKtjU2evdC4EXQQ136kX4hUe9wqNB7xH8v2AUqVChnlJ5Zo2in2VVuEjMAgHtFrTvoBN4ZAKkaKz6kv76Qrp06nxv47tyM3MR7PqskF50yXHbH0OSOCGw0oV5FaHKY8syDXWa_AUYh75iBnmiOx-A&state=34fFs29kd09')

# %%
dat = pd.read_csv('audio_features_full/features_full.csv')

# %%
dat
# Out:
#                       track_id                                     name  \
# 0       6Nd6ntkzr4t8o1FKPGOSMt          Here I Go Again - 2018 Remaster
# 1       31DvHUCSioX0JD7B4kZMJ9                        Money For Nothing
# 2       6yBbmHFTxihIDFAerzDMGi                            Hold On Tight
# 3       2E2ZVy2fxslpAUgbb4zu84                              Abracadabra
# 4       17lu4tymfnhmcIDlzBbtAb  For Those About to Rock (We Salute You)
# ...                        ...                                      ...
# 178001  099HTqcj7CVUhhEX37HAVO                         "Die Zauberflöte
# 178002  7yaC9Ex1Tr63bXQJKuQmzx                              Broken Love
# 178003  6gD72JkhAT2zdX2GM5qzgR                        Mi Fai Stare Bene
# 178004  6uOM2nnMDyiWFqIIPKc155                              Barbie Girl
# 178005  7wzcyrNodEDUN1AFLcpKnS                                Glory Box
#
#                       album_id               artist_id release_date  \
# ...

# %%
sim_test = pd.DataFrame([dat.iloc[4, 1]]*(len(dat)-5))

song_sim = [cosine_similarity(x, dat.iloc[4, np.r_[5:16, 21:23]].values) for x in dat.iloc[5:, np.r_[5:16, 21:23]].values]

# %%
sim_test['song_b'] = dat.iloc[5:, 1]
sim_test['song_b_id'] = dat.iloc[5:, 0]
sim_test['song_b_artist_id'] = dat.iloc[5:, 3]
sim_test['sim'] = song_sim
sim_test = sim_test.sort_values('sim', ascending=False)

# %%
sim_test
# Out:
#                                               0  \
# 169065  For Those About to Rock (We Salute You)
# 169064  For Those About to Rock (We Salute You)
# 62924   For Those About to Rock (We Salute You)
# 125580  For Those About to Rock (We Salute You)
# 73728   For Those About to Rock (We Salute You)
# ...                                         ...
# 134324  For Those About to Rock (We Salute You)
# 129476  For Those About to Rock (We Salute You)
# 164948  For Those About to Rock (We Salute You)
# 127661  For Those About to Rock (We Salute You)
# 104962  For Those About to Rock (We Salute You)
#
#                                  song_b               song_b_id  \
# 169065           "Piano Trio in A Minor  6wW0LPPpJy9W2diwreuZRn
# 169064                       "Swan Lake  124VApJemchjGC26NOOW2z
# 62924       The Horrors - 2012 Remaster  4A1vyzKMuqNrwuCuju7EkR
# 125580                         Señorita  4D0zi236oJxnP9qiJvZqSs
# ...

# %%
artist_ids = [x for x in sim_test.iloc[:25]['song_b_artist_id']]

# %%
genres = [cpp.get_artists(id)['genres'] if 'response' not in cpp.get_artists(id).keys() and cpp.get_artists(id)['genres'] != [] else None for id in artist_ids]

# %%
genres_sim = [round(jaccard_similarity(np.array(cpp.get_artists(dat.iloc[4, 3])['genres']), np.array(x)), 1) for x in genres if x is not None]

# %%
get_playlists_results = """{
  "href": "https://api.spotify.com/v1/users/1252723390/playlists?offset=0&limit=20",
  "items": [
    {
      "collaborative": false,
      "description": "",
      "external_urls": {
        "spotify": "https://open.spotify.com/playlist/5Vni0W2xkRu98e0g5ofm8i"
      },
      "href": "https://api.spotify.com/v1/playlists/5Vni0W2xkRu98e0g5ofm8i",
      "id": "5Vni0W2xkRu98e0g5ofm8i",
      "images": [
        {
          "height": 640,
          "url": "https://mosaic.scdn.co/640/ab67616d0000b27323a37302ff3d1cb55902e5b6ab67616d0000b27323fb02f383f3bef16ab9d092ab67616d0000b273c244c88cbb5e200d886a5d2cab67616d0000b273c9041c54ada6448f089fecd8",
          "width": 640
        },
        {
          "height": 300,
          "url": "https://mosaic.scdn.co/300/ab67616d0000b27323a37302ff3d1cb55902e5b6ab67616d0000b27323fb02f383f3bef16ab9d092ab67616d0000b273c244c88cbb5e200d886a5d2cab67616d0000b273c9041c54ada6448f089fecd8",
          "width": 300
        },
        {
          "height": 60,
          "url": "https://mosaic.scdn.co/60/ab67616d0000b27323a37302ff3d1cb55902e5b6ab67616d0000b27323fb02f383f3bef16ab9d092ab67616d0000b273c244c88cbb5e200d886a5d2cab67616d0000b273c9041c54ada6448f089fecd8",
          "width": 60
        }
      ],
      "name": "Good morning ",
      "owner": {
        "display_name": "Zackary Redman",
        "external_urls": {
          "spotify": "https://open.spotify.com/user/redmanthagod"
        },
        "href": "https://api.spotify.com/v1/users/redmanthagod",
        "id": "redmanthagod",
        "type": "user",
        "uri": "spotify:user:redmanthagod"
      },
      "primary_color": null,
      "public": false,
      "snapshot_id": "MjEsMWNhYjg1MWZkYWQ0MDUzOWE3NmM4MTY3MjQ3OGY3OGQ2YzA5ZDAyZg==",
      "tracks": {
        "href": "https://api.spotify.com/v1/playlists/5Vni0W2xkRu98e0g5ofm8i/tracks",
        "total": 20
      },
      "type": "playlist",
      "uri": "spotify:playlist:5Vni0W2xkRu98e0g5ofm8i"
    },
    {
      "collaborative": false,
      "description": "",
      "external_urls": {
        "spotify": "https://open.spotify.com/playlist/4jPHTgasaoBMEV9ZTB7mZf"
      },
      "href": "https://api.spotify.com/v1/playlists/4jPHTgasaoBMEV9ZTB7mZf",
      "id": "4jPHTgasaoBMEV9ZTB7mZf",
      "images": [
        {
          "height": 640,
          "url": "https://mosaic.scdn.co/640/ab67616d0000b27370fbdc9191bace769ae0a0a5ab67616d0000b273a4d73b32e40487605c73cffeab67616d0000b273e2accda06ebadfe3014c161bab67616d0000b273f43405f32dfe1c07777c06af",
          "width": 640
        },
        {
          "height": 300,
          "url": "https://mosaic.scdn.co/300/ab67616d0000b27370fbdc9191bace769ae0a0a5ab67616d0000b273a4d73b32e40487605c73cffeab67616d0000b273e2accda06ebadfe3014c161bab67616d0000b273f43405f32dfe1c07777c06af",
          "width": 300
        },
        {
          "height": 60,
          "url": "https://mosaic.scdn.co/60/ab67616d0000b27370fbdc9191bace769ae0a0a5ab67616d0000b273a4d73b32e40487605c73cffeab67616d0000b273e2accda06ebadfe3014c161bab67616d0000b273f43405f32dfe1c07777c06af",
          "width": 60
        }
      ],
      "name": "Party On",
      "owner": {
        "display_name": "KEVtheDEV",
        "external_urls": {
          "spotify": "https://open.spotify.com/user/k3v1nl01"
        },
        "href": "https://api.spotify.com/v1/users/k3v1nl01",
        "id": "k3v1nl01",
        "type": "user",
        "uri": "spotify:user:k3v1nl01"
      },
      "primary_color": null,
      "public": false,
      "snapshot_id": "NyxkMGFmMTViNmQ2NmE3YjAwZWY1ZDJjNGI0NjU0MGMyZjhiMDdmNzEz",
      "tracks": {
        "href": "https://api.spotify.com/v1/playlists/4jPHTgasaoBMEV9ZTB7mZf/tracks",
        "total": 96
      },
      "type": "playlist",
      "uri": "spotify:playlist:4jPHTgasaoBMEV9ZTB7mZf"
    },
    {
      "collaborative": false,
      "description": "",
      "external_urls": {
        "spotify": "https://open.spotify.com/playlist/4Hy9f7CqrLNkbcGfymWgJk"
      },
      "href": "https://api.spotify.com/v1/playlists/4Hy9f7CqrLNkbcGfymWgJk",
      "id": "4Hy9f7CqrLNkbcGfymWgJk",
      "images": [
        {
          "height": null,
          "url": "https://i.scdn.co/image/ab67706c0000bebbe0feb7eda593a03eb010a537",
          "width": null
        }
      ],
      "name": "hell nah don’t discriminize 🔮",
      "owner": {
        "display_name": "15makj",
        "external_urls": {
          "spotify": "https://open.spotify.com/user/15makj"
        },
        "href": "https://api.spotify.com/v1/users/15makj",
        "id": "15makj",
        "type": "user",
        "uri": "spotify:user:15makj"
      },
      "primary_color": null,
      "public": false,
      "snapshot_id": "MTQzLGY0ZTc3ZjU5NDJhOGI2MGZjMGI3MTAwZjQ2NWRkZDQ2Mzg3ZGJjNzM=",
      "tracks": {
        "href": "https://api.spotify.com/v1/playlists/4Hy9f7CqrLNkbcGfymWgJk/tracks",
        "total": 206
      },
      "type": "playlist",
      "uri": "spotify:playlist:4Hy9f7CqrLNkbcGfymWgJk"
    },
    {
      "collaborative": false,
      "description": "",
      "external_urls": {
        "spotify": "https://open.spotify.com/playlist/5MoFfUjvdBldrwKrJnOQrt"
      },
      "href": "https://api.spotify.com/v1/playlists/5MoFfUjvdBldrwKrJnOQrt",
      "id": "5MoFfUjvdBldrwKrJnOQrt",
      "images": [
        {
          "height": 640,
          "url": "https://mosaic.scdn.co/640/ab67616d0000b2737028679269dc6a5a29ce8f36ab67616d0000b27388883701231713b18429f80bab67616d0000b273f3d5966c161176c6d72fc3b3ab67616d0000b273f9ab90760af53893168b0b67",
          "width": 640
        },
        {
          "height": 300,
          "url": "https://mosaic.scdn.co/300/ab67616d0000b2737028679269dc6a5a29ce8f36ab67616d0000b27388883701231713b18429f80bab67616d0000b273f3d5966c161176c6d72fc3b3ab67616d0000b273f9ab90760af53893168b0b67",
          "width": 300
        },
        {
          "height": 60,
          "url": "https://mosaic.scdn.co/60/ab67616d0000b2737028679269dc6a5a29ce8f36ab67616d0000b27388883701231713b18429f80bab67616d0000b273f3d5966c161176c6d72fc3b3ab67616d0000b273f9ab90760af53893168b0b67",
          "width": 60
        }
      ],
      "name": "🚗 Drive 🚗",
      "owner": {
        "display_name": "Alex Borowy",
        "external_urls": {
          "spotify": "https://open.spotify.com/user/12124603229"
        },
        "href": "https://api.spotify.com/v1/users/12124603229",
        "id": "12124603229",
        "type": "user",
        "uri": "spotify:user:12124603229"
      },
      "primary_color": null,
      "public": false,
      "snapshot_id": "MzY4LDMxMmE4ZDk3MWVjNTlkOGQwNmIzMGE1ZTFjOGNiNzVjMzE1NjkxYTE=",
      "tracks": {
        "href": "https://api.spotify.com/v1/playlists/5MoFfUjvdBldrwKrJnOQrt/tracks",
        "total": 373
      },
      "type": "playlist",
      "uri": "spotify:playlist:5MoFfUjvdBldrwKrJnOQrt"
    },
    {
      "collaborative": false,
      "description": "everything idk how to categorize",
      "external_urls": {
        "spotify": "https://open.spotify.com/playlist/1LJXyMUkFOdbJ3avRyRap0"
      },
      "href": "https://api.spotify.com/v1/playlists/1LJXyMUkFOdbJ3avRyRap0",
      "id": "1LJXyMUkFOdbJ3avRyRap0",
      "images": [
        {
          "height": null,
          "url": "https://i.scdn.co/image/ab67706c0000bebbdb3fa9f1f967eae76af70967",
          "width": null
        }
      ],
      "name": "i simp for lin beifong",
      "owner": {
        "display_name": "15makj",
        "external_urls": {
          "spotify": "https://open.spotify.com/user

          "width": 640
        },
        {
          "height": 300,
          "url": "https://mosaic.scdn.co/300/ab67616d0000b273539feea5aa5cf539bb687ae7ab67616d0000b2736d195fac8c47ff0500af066fab67616d0000b27371610df454ab8371e9b18682ab67616d0000b273812cd368a42388b154ceacb8",
          "width": 300
        },
        {
          "height": 60,
          "url": "https://mosaic.scdn.co/60/ab67616d0000b273539feea5aa5cf539bb687ae7ab67616d0000b2736d195fac8c47ff0500af066fab67616d0000b27371610df454ab8371e9b18682ab67616d0000b273812cd368a42388b154ceacb8",
          "width": 60
        }
      ],
      "name": "xиты СССР",
      "owner": {
        "display_name": "Alex Ilyin",
        "external_urls": {
          "spotify": "https://open.spotify.com/user/1252723390"
        },
        "href": "https://api.spotify.com/v1/users/1252723390",
        "id": "1252723390",
        "type": "user",
        "uri": "spotify:user:1252723390"
      },
      "primary_color": null,
      "public": false,
      "snapshot_id": "MTgsNjE2YTViN2YyNWM1ODYwNGZiY2ZlZjBkOGM3ZDBiMDJkOTU3OWM3NA==",
      "tracks": {
        "href": "https://api.spotify.com/v1/playlists/0pPZzJTD0eOj7tYRFd4VLr/tracks",
        "total": 9
      },
      "type": "playlist",
      "uri": "spotify:playlist:0pPZzJTD0eOj7tYRFd4VLr"
    },
    {
      "collaborative": false,
      "description": "Music from Moneybagg Yo, Lil Mosey and Tee Grizzley.",
      "external_urls": {
        "spotify": "https://open.spotify.com/playlist/37i9dQZF1DX0XUsuxWHRQd"
      },
      "href": "https://api.spotify.com/v1/playlists/37i9dQZF1DX0XUsuxWHRQd",
      "id": "37i9dQZF1DX0XUsuxWHRQd",
      "images": [
        {
          "height": null,
          "url": "https://i.scdn.co/image/ab67706f00000003f1cf4be990a8fab7b4b04ed6",
          "width": null
        }
      ],
      "name": "RapCaviar",
      "owner": {
        "display_name": "Spotify",
        "external_urls": {
          "spotify": "https://open.spotify.com/user/spotify"
        },
        "href": "https://api.spotify.com/v1/users/spotify",
        "id": "spotify",
        "type": "user",
        "uri": "spotify:user:spotify"
      },
      "primary_color": null,
      "public": false,
      "snapshot_id": "MTYxNjEyNjYzNSwwMDAwMDU1ZDAwMDAwMTc4NDhhNzZkZDYwMDAwMDE3ODQ2N2M3Y2Q3",
      "tracks": {
        "href": "https://api.spotify.com/v1/playlists/37i9dQZF1DX0XUsuxWHRQd/tracks",
        "total": 50
      },
      "type": "playlist",
      "uri": "spotify:playlist:37i9dQZF1DX0XUsuxWHRQd"
    },
    {
      "collaborative": false,
      "description": "",
      "external_urls": {
        "spotify": "https://open.spotify.com/playlist/0aoE3U7tA0MYhvoUaKGiC7"
      },
      "href": "https://api.spotify.com/v1/playlists/0aoE3U7tA0MYhvoUaKGiC7",
      "id": "0aoE3U7tA0MYhvoUaKGiC7",
      "images": [
        {
          "height": 640,
          "url": "https://mosaic.scdn.co/640/ab67616d0000b2731ffb217692ce86e056886106ab67616d0000b27346e1307c35579c3483ea7b03ab67616d0000b273569f6e71b5644c6a48927f3fab67616d0000b27357928e0363878a71692e6a1f",
          "width": 640
        },
        {
          "height": 300,
          "url": "https://mosaic.scdn.co/300/ab67616d0000b2731ffb217692ce86e056886106ab67616d0000b27346e1307c35579c3483ea7b03ab67616d0000b273569f6e71b5644c6a48927f3fab67616d0000b27357928e0363878a71692e6a1f",
          "width": 300
        },
        {
          "height": 60,
          "url": "https://mosaic.scdn.co/60/ab67616d0000b2731ffb217692ce86e056886106ab67616d0000b27346e1307c35579c3483ea7b03ab67616d0000b273569f6e71b5644c6a48927f3fab67616d0000b27357928e0363878a71692e6a1f",
          "width": 60
        }
      ],
      "name": "playlist2",
      "owner": {
        "display_name": "Alex Ilyin",
        "external_urls": {
          "spotify": "https://open.spotify.com/user/1252723390"
        },
        "href": "https://api.spotify.com/v1/users/1252723390",
        "id": "1252723390",
        "type": "user",
        "uri": "spotify:user:1252723390"
      },
      "primary_color": null,
      "public": true,
      "snapshot_id": "NDAsZGU0NGUzYWYxYzIwNzA3MmFhYzliMzVhMDU3MDdjNTcyZGQyN2Y1NA==",
      "tracks": {
        "href": "https://api.spotify.com/v1/playlists/0aoE3U7tA0MYhvoUaKGiC7/tracks",
        "total": 24
      },
      "type": "playlist",
      "uri": "spotify:playlist:0aoE3U7tA0MYhvoUaKGiC7"
    },
    {
      "collaborative": false,
      "description": "",
      "external_urls": {
        "spotify": "https://open.spotify.com/playlist/3QEQWMCmrXokeBVpwLm8IA"
      },
      "href": "https://api.spotify.com/v1/playlists/3QEQWMCmrXokeBVpwLm8IA",
      "id": "3QEQWMCmrXokeBVpwLm8IA",
      "images": [
        {
          "height": 640,
          "url": "https://mosaic.scdn.co/640/ab67616d0000b2739c1e02d4becb7c5bbca01e2aab67616d0000b273a1e867d40e7bb29ced5c0194ab67616d0000b273f54b99bf27cda88f4a7403ceab67616d0000b273f907de96b9a4fbc04accc0d5",
          "width": 640
        },
        {
          "height": 300,
          "url": "https://mosaic.scdn.co/300/ab67616d0000
          "width": 300
        },
        {
          "height": 60,
          "url": "https://mosaic.scdn.co/60/ab67616d0000b273114a58e180412e0f2d3745acab67616d0000b2736d3e1f8b91f65eaab52e85abab67616d0000b27381106b7ade8ee85b56545f71ab67616d0000b273da2e4a4059497dbf17a9bb78",
          "width": 60
        }
      ],
      "name": "Classical",
      "owner": {
        "display_name": "Alex Ilyin",
        "external_urls": {
          "spotify": "https://open.spotify.com/user/1252723390"
        },
        "href": "https://api.spotify.com/v1/users/1252723390",
        "id": "1252723390",
        "type": "user",
        "uri": "spotify:user:1252723390"
      },
      "primary_color": null,
      "public": false,
      "snapshot_id": "NzAsM2UxYmUwMzg2MzBhZDI3ZGNmOTExOWY5MzgyMzYxNGU0ZjQ0NmFjOQ==",
      "tracks": {
        "href": "https://api.spotify.com/v1/playlists/770uJ8ZFCHxuJxgwhkvrhj/tracks",
        "total": 53
      },
      "type": "playlist",
      "uri": "spotify:playlist:770uJ8ZFCHxuJxgwhkvrhj"
    },
    {
      "collaborative": false,
      "description": "Chillout hip-hop vibes. Cover: JID",
      "external_urls": {
        "spotify": "https://open.spotify.com/playlist/37i9dQZF1DWT6MhXz0jw61"
      },
      "href": "https://api.spotify.com/v1/playlists/37i9dQZF1DWT6MhXz0jw61",
      "id": "37i9dQZF1DWT6MhXz0jw61",
      "images": [
        {
          "height": null,
          "url": "https://i.scdn.co/image/ab67706f0000000326d4ff167deb19679fb9ad0a",
          "width": null
        }
      ],
      "name": "Mellow Bars",
      "owner": {
        "display_name": "Spotify",
        "external_urls": {
          "spotify": "https://open.spotify.com/user/spotify"
        },
        "href": "https://api.spotify.com/v1/users/spotify",
        "id": "spotify",
        "type": "user",
        "uri": "spotify:user:spotify"
      },
      "primary_color": null,
      "public": false,
      "snapshot_id": "MTYxNjEyNjQwMCwwMDAwMDE2ODAwMDAwMTc4NDhhM2Q3MDgwMDAwMDE3N2ZiNWJlYzc4",
      "tracks": {
        "href": "https://api.spotify.com/v1/playlists/37i9dQZF1DWT6MhXz0jw61/tracks",
        "total": 99
      },
      "type": "playlist",
      "uri": "spotify:playlist:37i9dQZF1DWT6MhXz0jw61"
    }
  ],
  "limit": 20,
  "next": "https://api.spotify.com/v1/users/1252723390/playlists?offset=20&limit=20",
  "offset": 0,
  "previous": null,
  "total": 21
}"""

# %%
def get_song_artist_df(followed_playlists):
    # Take the playlists that a user follows. For each playlist in that list, create a dictionary having keys set to each unique track ID, with values set to 
    # the artists that are featured on that track. 
    
    followed_tracks_artists = {}
    for playlist_id in followed_playlists:
        try:
            res = cpp.get_playlists(False, '', playlist_id, 'tracks')
            for track in res['items']:
                if track['track']['id'] not in followed_tracks_artists.keys():
                    followed_tracks_artists[track['track']['id']] = [art['id'] for art in track['track']['artists']]
                else:
                    for artist in track['track']['artists']:
                        followed_tracks_artists[track['track']['id']].append(artist['id'])
        except Exception as e:
            print(e)
            pass

    # Create a DataFrame containing with each row containing a unique artist-track combinations 

    followed_tracks_df = pd.DataFrame(columns=['track', 'artist'])

    for track in followed_tracks_artists.keys():
        for row in followed_tracks_artists[track]:
            followed_tracks_df = followed_tracks_df.append({'track': track, 'artist': row}, ignore_index=True)
    
    # Now that we have a DataFrame of unique artist-track combinations, we want to find the genres for each unique artist. Spotify does not release track genre information
    # through its API, for this reason we have to find the genre of the artist. We will use this genre information to filter the final DataFrame to match genres with the song/artist
    # that is currently being listened to

    artist_genre = {}
    for artist_id in followed_tracks_df['artist'].unique():
        if artist_id not in artist_genre.keys():
            artist_genre[artist_id] = cpp.get_artists(artist_id)['genres'] if cpp.get_artists(artist_id)['genres'] != [] and 'genres' in cpp.get_artists(artist_id).keys() else None
    
    # For the newly created artist_genre dictionary above, match each artist ID in our previously created DataFrame with its genre in the dictionary. Use this to create a new 'genre'
    # column in the DataFrame. Filter out any artists that do not have genre information

    followed_tracks_df['genres'] = [artist_genre[id] for id in followed_tracks_df['artist']]
    followed_tracks_df = followed_tracks_df[followed_tracks_df['genres'].notna()]

    # For the newly created 'genre' column, split the genres into words and create a union of those words for each artist. The reason we do this is that Spotify contains a lot of unique 
    # genres. Since we have a rather small dataset, we want to split more rare genres such as 'german hip hop' into a set ('german', 'hip', 'hop') so that this song will match with other 
    # german or hip-hop tracks
    
    followed_tracks_df['genre_words'] = [list_union([word for word in [genre_string.split(' ') for genre_string in genre_list]]) for genre_list in followed_tracks_df['genres'].values]

    return followed_tracks_df

# %%
def current_song_info(song_id)->tuple:
    # For the current song, get the song's artists and the genres for those artists

    track_info = cpp.get_tracks(song_id)
    
    current_artists = [artist['id'] for artist in track_info['artists']]
    current_genres = {}
    for artist in current_artists:
        try:
            current_genres[artist] = cpp.get_artists(artist)['genres']
        except Exception as e:
            current_genres[artist] = None
                
    return current_genres

# %%
def get_audio_features(tracks, existing_data):
    # Create a dictionary of tracks and their audio features. If the song exists in the current dataset, retrieve that information. If it doesn't, retrieve the information from the 
    # Spotify API 

    audio_features = {}
    for id in tracks:
        if id in existing_data['track_id'].values:
            audio_features[id] = existing_data[existing_data['track_id']==id].iloc[:, np.r_[5:16, 21:23]].values.tolist()
        else:
            try:
                audio_features[id] = list({k:v for k,v in cpp.get_tracks(id, 'audio-features').items() if k in existing_data.columns[np.r_[5:16, 21:23]].values}.values())
            except:
                pass 
    
    return audio_features

# %%
def song_rec(user_id, get_playlists_results, current_song, stored_songs)->str:
    # Given a user_id, find all playlists that the user follows. Using this logic, we can create a set of tracks listened to by users that created these followed playlists.
    # Since the Spotify API does not let us find followed users, this is our best bet for collaborative filtering

    followed_playlists = [playlist['id'] for playlist in json.loads(get_playlists_results)['items'] if playlist['owner']['id'] != user_id]
    
    # Call the two functions above to get information for tracks contained in 'followed playlists', as well as track information for the current song

    followed_tracks_df = get_song_artist_df(followed_playlists)
    current_genres = current_song_info(current_song)

    # For the genres of the current song/artist(s)
    
    current_genres_words = list_union([word for word in [dict_values.split(' ') for all_genres in current_genres.values() for dict_values in all_genres]])
    
    # Find the set Jaccard distance between the genres of the current song/artist(s) and all the songs in our followed tracks dataset. Since Spotify has unique genre naming conventions,
    # it will be harder to find exact matches for sets of genres 
    
    followed_tracks_df['jac_dist'] = [round(jaccard_similarity(np.array(current_genres_words), np.array(followed_genre)), 2) for followed_genre in followed_tracks_df['genre_words']]

    # Keep songs which genre sets have Jaccard distance greater than or equal to 0.4 
    
    followed_tracks_df = followed_tracks_df[followed_tracks_df['jac_dist'] >= 0.4] 

    # Get the audio features for the songs in the remaining dataset
    
    followed_tracks_audio_features = audio_features(followed_tracks_df['track'].unique(), stored_songs)

    # Set the audio_features retrieved above as a new column in the dataframe
    
    followed_tracks_df['audio_features'] = [followed_tracks_audio_features[track] if track in followed_tracks_audio_features else None for x in left_tracks['track']]
    followed_tracks_df = followed_tracks_df[followed_tracks_df['audio_features'].notna()]

    # Get the audio_features of the current song. We will be calculating the cosine similarity of the audio features of the current song to each song in our dataframe
    
    af_list_values = list({k:v for k,v in cpp.get_tracks(current_song, 'audio-features').items() if k in stored_songs.columns[np.r_[5:16, 21:23]].values}.values())

    # Now that we have the audio features of the current song and the songs with closely matching genres, we can calculate cosine similarity

    followed_tracks_df['cosine_sim'] = [cosine_similarity(np.array(af_list_values), stored_songs.iloc[x, np.r_[5:16, 21:23]].values) for x in range(len(left_tracks))]
    followed_tracks_df.sort_values(['jac_dist', 'cosine_sim'], ascending=False)
   
    return followed_tracks_df

# %%
followed_playlists = song_rec('1252723390', get_playlists_results, '0DAQryfUiFZdWFo76RYBc8', dat)
# Out:
# ./CPPotify/source/py/CPPotify.py:425: UserWarning: Spotify token has expired. No action needed, generating new token...
#   warnings.warn(
# ./CPPotify/source/py/CPPotify.py:431: UserWarning: New Spotify token created
#   warnings.warn("New Spotify token created")
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Desktop/SpotifyRecSystem/env/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
test = get_audio_features(followed_playlists[followed_playlists['jac_dist']>=0.4]['track'].unique(), dat)

# %%
followed_playlists
# Out:
#                       track                  artist  \
# 0    2uFUJAyfS7de4VTKNwZWZc  2FEdyVgGMSclOsYJ4wAQUY
# 1    6lIRYe72fn1pf7TNqfI0ul  6iWuBN32BqCJAeXW6o3nil
# 2    6lIRYe72fn1pf7TNqfI0ul  0NB5HROxc8dDBXpkIi1v3d
# 3    6lIRYe72fn1pf7TNqfI0ul  4Qz5J3GBpmR1LcPgqFbzlW
# 4    6lIRYe72fn1pf7TNqfI0ul  4iMO20EPodreIaEl8qW66y
# ..                      ...                     ...
# 512  2VIbFXPOrA6dDpCOT7iWvo  5ZK5YGazICLXEXlaNnEBqP
# 513  5DACjLIdsB7WNjREalxp75  1URwpSLjCBhRjnw4SUwNyL
# 514  41OEsivuDXUUKWqVPhCZzU  0ABk515kENDyATUdpCKVfW
# 515  41OEsivuDXUUKWqVPhCZzU  53S3boqktbqiB1JfHzsu1f
# 516  3vl2uH4D2QItFFhzz5L06g  20WmX0l9JgOpehDOAXY6iO
#
#                                                 genres  \
# 0                            [bedroom soul, chill r&b]
# 1    [alternative r&b, chill r&b, indie r&b, nyc po...
# 2    [alternative r&b, indie pop, indie r&b, modern...
# 3                          [bedroom soul, lo-fi beats]
# 4       [bedroom pop, modern rock, oakland indie, pop]
# ...

# %%
audio_features = {}
for id in followed_playlists[followed_playlists['jac_dist']>=0.4]['track'].unique():
    if id in dat['track_id'].values:
        audio_features[id] = dat[dat['track_id']==id].iloc[:, np.r_[5:16, 21:23]].values.tolist()
    else:
        try:
            audio_features[id] = list({k:v for k,v in cpp.get_tracks(id, 'audio-features').items() if k in dat.columns[np.r_[5:16, 21:23]].values}.values())
        except:
            pass

# %%
left_tracks = followed_playlists[followed_playlists['jac_dist']>=0.4]
left_tracks['audio_features'] = [audio_features[x] if x in audio_features else None for x in left_tracks['track']]
# Out:
# <ipython-input-125-452aaf470b5b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   left_tracks['audio_features'] = [audio_features[x] if x in audio_features else None for x in left_tracks['track']]

# %%
current_song_af = cpp.get_tracks('0DAQryfUiFZdWFo76RYBc8', 'audio-features')

af_list_values = list({k:v for k,v in current_song_af.items() if k in dat.columns[np.r_[5:16, 21:23]].values}.values())

# %%
test = [dat.iloc[x, np.r_[5:16, 21:23]].values for x in range(len(left_tracks))]

# %%
left_tracks['cosine_sim'] = [cosine_similarity(np.array(af_list_values), dat.iloc[x, np.r_[5:16, 21:23]].values) for x in range(len(left_tracks))]
# Out:
# <ipython-input-153-1435c0d845ed>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   left_tracks['cosine_sim'] = [cosine_similarity(np.array(af_list_values), dat.iloc[x, np.r_[5:16, 21:23]].values) for x in range(len(left_tracks))]

# %%
left_tracks.sort_values(['jac_dist', 'cosine_sim'], ascending=False)
# Out:
#                       track                  artist  \
# 468  7ypuC93uVLeCbU58TtKQg9  2AfU5LYBVCiCtuCCfM7uVX
# 443  2Wp2IjSLARq1XaoIMaDgCp  2848adRcxvgWNRcz1g1tQD
# 442  7r1lqyEW3iyZ39TDFnzI4p  2AfU5LYBVCiCtuCCfM7uVX
# 447  49nkBg3OJtp6m6TQPmG1Qw  2AfU5LYBVCiCtuCCfM7uVX
# 444  2Wp2IjSLARq1XaoIMaDgCp  2AfU5LYBVCiCtuCCfM7uVX
# 470  1jNKhbKmDgYSHHSCEeMXey  2AfU5LYBVCiCtuCCfM7uVX
# 362  65OVbaJR5O1RmwOQx0875b  3TVXtAsR1Inumwj472S9r4
# 76   2Xqd0wUttjueBfdcltADOv  02kJSzxNuaWGqwubyUba0Z
# 430  3Kwdm0iLyEiRB8InsZoo6n  3TVXtAsR1Inumwj472S9r4
# 193  1auxYwYrFRqZP7t3s7w4um  3nFkdlSjzX9mRTtwJOzDYB
# 121  27GmP9AWRs744SzKcpJsTZ  3TVXtAsR1Inumwj472S9r4
# 125  794QVQtFNy7hvtjQP1keQd  02kJSzxNuaWGqwubyUba0Z
# 206  7Fa5UNizycSms5jP3SQD3F  3nFkdlSjzX9mRTtwJOzDYB
# 62   4XoP1AkbOurU9CeZ2rMEz2  3TVXtAsR1Inumwj472S9r4
# 229  7AijU6oTPGmG64uWf63Qvc  68DWke2VjdDmA75aJX5C57
# 94   6fwdbPMwP1zVStm8FybmkO  0iEtIxbK0KxaSlF7G42ZOp
# 368  4FRW5Nza1Ym91BGV4nFWXI  3TVXtAsR1Inumwj472S9r4
# ...

# %%
song_sim = [cosine_similarity(x, dat.iloc[4, np.r_[5:16, 21:23]].values) for x in dat.iloc[5:, np.r_[5:16, 21:23]].values]
